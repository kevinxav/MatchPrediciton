# %%
import pandas as pd
matches=pd.read_csv('matches.csv')
matches.head()
# Out:
#    Unnamed: 0        date   time     comp        round  day venue result   gf  \
# 0           0  2021-08-14  22:00  La Liga  Matchweek 1  Sat  Home      L  1.0
# 1           1  2021-08-21  17:00  La Liga  Matchweek 2  Sat  Home      L  0.0
# 2           2  2021-08-27  22:15  La Liga  Matchweek 3  Fri  Away      L  0.0
# 3           3  2021-09-18  21:00  La Liga  Matchweek 5  Sat  Home      L  0.0
# 4           4  2021-09-22  19:30  La Liga  Matchweek 6  Wed  Away      L  0.0
#
#     ga  ...  match report  notes    sh  sot  dist   fk pk pkatt season    team
# 0  4.0  ...  Match Report    NaN  10.0  3.0  18.4  1.0  1     1   2021  Alaves
# 1  1.0  ...  Match Report    NaN   9.0  4.0  14.8  0.0  0     0   2021  Alaves
# 2  3.0  ...  Match Report    NaN   9.0  2.0  19.7  1.0  0     0   2021  Alaves
# 3  2.0  ...  Match Report    NaN   8.0  3.0  22.6  0.0  0     0   2021  Alaves
# 4  1.0  ...  Match Report    NaN   7.0  2.0  14.9  0.0  0     0   2021  Alaves
#
# [5 rows x 28 columns]

# %%
matches.tail()
# Out:
#       Unnamed: 0        date   time     comp         round  day venue result  \
# 2009          36  2020-07-05  22:00  La Liga  Matchweek 34  Sun  Home      L
# 2010          37  2020-07-08  20:30  La Liga  Matchweek 35  Wed  Away      W
# 2011          38  2020-07-13  19:30  La Liga  Matchweek 36  Mon  Home      L
# 2012          39  2020-07-16  21:00  La Liga  Matchweek 37  Thu  Away      L
# 2013          40  2020-07-19  18:30  La Liga  Matchweek 38  Sun  Home      W
#
#        gf   ga  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 2009  1.0  4.0  ...  Match Report    NaN   9.0  4.0  18.3  0.0  0     0
# 2010  3.0  1.0  ...  Match Report    NaN   4.0  1.0  26.9  0.0  2     2
# 2011  1.0  2.0  ...  Match Report    NaN   9.0  3.0  21.2  1.0  0     0
# 2012  1.0  2.0  ...  Match Report    NaN   8.0  4.0  18.6  2.0  0     0
# 2013  4.0  0.0  ...  Match Report    NaN  12.0  5.0  14.0  0.0  0     0
#
#      season        team
# 2009   2022  Villarreal
# ...

# %%
matches.columns
# Out:
# Index(['Unnamed: 0', 'date', 'time', 'comp', 'round', 'day', 'venue', 'result',
#        'gf', 'ga', 'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain',
#        'formation', 'referee', 'match report', 'notes', 'sh', 'sot', 'dist',
#        'fk', 'pk', 'pkatt', 'season', 'team'],
#       dtype='object')

# %%
sns.histplot(matches['gf'],kde=True)
plt.title('Distribution of Goals')
plt.show()

# %%
matches.describe()
# Out:
#         Unnamed: 0           gf           ga           xg          xga  \
# count  2014.000000  2014.000000  2014.000000  2014.000000  2014.000000
# mean     22.153923     1.234359     1.263654     1.216981     1.240765
# std      13.885528     1.157576     1.171571     0.747415     0.760560
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      10.000000     0.000000     0.000000     0.700000     0.700000
# 50%      22.000000     1.000000     1.000000     1.100000     1.100000
# 75%      34.000000     2.000000     2.000000     1.600000     1.700000
# max      57.000000     6.000000     6.000000     4.900000     4.900000
#
#               poss    attendance  notes           sh          sot  \
# count  2014.000000   1303.000000    0.0  2014.000000  2014.000000
# mean     49.707051  25474.092863    NaN    11.079940     3.640020
# std      11.502590  17617.000204    NaN     4.625365     2.224599
# ...

# %%
print(matches.isnull().sum())
# Out:
# Unnamed: 0         0
# date               0
# time               0
# comp               0
# round              0
# day                0
# venue              0
# result             0
# gf                 0
# ga                 0
# opponent           0
# xg                 0
# xga                0
# poss               0
# attendance       711
# captain            0
# formation          0
# referee            0
# match report       0
# notes           2014
# sh                 0
# sot                0
# dist               2
# fk                 0
# pk                 0
# pkatt              0
# season             0
# team               0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x='result', data=matches)
plt.xlabel('result')
plt.show()

# %%
sns.pairplot(matches, hue='result')
plt.show()

# %%
matches['date'] = pd.to_datetime(matches['date'])
matches.set_index('date', inplace=True)
matches.resample('M').size().plot()
plt.title('Number of Matches Over Time')
plt.show()

# %%
# Assuming 'matches' is your DataFrame
correlation_matrix = matches.corr()
# Set the size of the plot
plt.figure(figsize=(12, 10))
# Create the heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# Set title and show the plot
plt.title('Correlation Matrix')
plt.show()

# %%
crosstab_result_venue = pd.crosstab(matches['result'], matches['venue'])
sns.heatmap(crosstab_result_venue, cmap='Blues', annot=True, fmt='d')
plt.title('Result vs Venue')
plt.show()

# %%
sns.histplot(matches['poss'], bins=20, kde=True)
plt.title('Distribution of Possession')
plt.show()

# %%
venue_avg_attendance = matches.groupby('venue')['attendance'].mean().sort_values(ascending=False)
sns.barplot(x=venue_avg_attendance.index, y=venue_avg_attendance.values)
plt.xticks(rotation=45, ha='right')
plt.title('Average Attendance by Venue')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'laliga_data' is your DataFrame

# Numerical features: Histograms or Kernel Density Plots
numerical_features = ['gf', 'ga', 'xg', 'attendance', 'sh', 'sot', 'dist', 'fk', 'pk', 'pkatt']

plt.figure(figsize=(15, 8))
for i, feature in enumerate(numerical_features, 1):
    plt.subplot(3, 4, i)
    sns.histplot(matches[feature], kde=True)
    plt.title(f'Distribution of {feature}')

plt.tight_layout()
plt.show()

# Categorical features: Bar Plots
categorical_features = ['result', 'round', 'day', 'venue', 'season']

plt.figure(figsize=(15, 8))
for i, feature in enumerate(categorical_features, 1):
    plt.subplot(2, 3, i)
    sns.countplot(x=feature, data=matches)
    plt.title(f'Distribution of {feature}')

plt.tight_layout()
plt.show()

# %%
matches["team"].value_counts()
# Out:
# Alaves             114
# Atletico Madrid    114
# Barcelona          114
# Real Betis         114
# Celta Vigo         114
# Getafe             114
# Granada            114
# Levante            114
# Athletic Club      114
# Real Madrid         76
# Eibar               76
# Villarreal          76
# Valencia            76
# Sevilla             76
# Real Sociedad       76
# Mallorca            76
# Osasuna             76
# Espanyol            76
# Elche               76
# Cadiz               76
# Rayo Vallecano      38
# Huesca              38
# Leganes             38
# Valladolid          38
# Name: team, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Scatter plot: Relationship between goals (gf) and rounds
plt.figure(figsize=(12, 6))
sns.scatterplot(x='round', y='gf', data=matches)
plt.title('Scatter Plot: Goals vs Rounds')
plt.xlabel('Round')
plt.ylabel('Goals Scored')
plt.show()

# Box plot: Distribution of goals (gf) across rounds
plt.figure(figsize=(14, 8))
sns.boxplot(x='round', y='gf', data=matches)
plt.title('Box Plot: Goals Distribution Across Rounds')
plt.xlabel('Round')
plt.ylabel('Goals Scored')
plt.show()

# Violin plot: Distribution of goals (gf) across opponents
plt.figure(figsize=(16, 8))
sns.violinplot(x='opponent', y='gf', data=matches)
plt.title('Violin Plot: Goals Distribution Across Opponents')
plt.xlabel('Opponent')
plt.ylabel('Goals Scored')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better visibility
plt.show()

# %%
# Assuming 'matches' is your DataFrame and 'date' is the time-related feature
# Make sure 'date' is in datetime format
matches['date'] = pd.to_datetime(matches['date'])

# Set 'date' as the index for time series analysis
matches.set_index('date', inplace=True)

# Create a time series plot
plt.figure(figsize=(12, 6))
matches['result'].resample('M').count().plot()  # Resample by month, you can adjust as needed
plt.title('Number of Matches Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Matches')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
matches["round"].value_counts()
# Out:
# Matchweek 1     53
# Matchweek 29    53
# Matchweek 22    53
# Matchweek 23    53
# Matchweek 24    53
# Matchweek 25    53
# Matchweek 26    53
# Matchweek 27    53
# Matchweek 28    53
# Matchweek 30    53
# Matchweek 2     53
# Matchweek 31    53
# Matchweek 32    53
# Matchweek 33    53
# Matchweek 34    53
# Matchweek 35    53
# Matchweek 36    53
# Matchweek 37    53
# Matchweek 21    53
# Matchweek 20    53
# Matchweek 19    53
# Matchweek 4     53
# Matchweek 3     53
# Matchweek 5     53
# Matchweek 6     53
# Matchweek 7     53
# Matchweek 8     53
# Matchweek 9     53
# Matchweek 10    53
# Matchweek 11    53
# Matchweek 12    53
# Matchweek 13    53
# Matchweek 14    53
# Matchweek 15    53
# Matchweek 16    53
# Matchweek 17    53
# Matchweek 18    53
# Matchweek 38    53
# Name: round, dtype: int64

# %%
matches.shape
# Out:
# (2014, 28)

# %%
matches["team"].value_counts()
# Out:
# Alaves             114
# Atletico Madrid    114
# Barcelona          114
# Real Betis         114
# Celta Vigo         114
# Getafe             114
# Granada            114
# Levante            114
# Athletic Club      114
# Real Madrid         76
# Eibar               76
# Villarreal          76
# Valencia            76
# Sevilla             76
# Real Sociedad       76
# Mallorca            76
# Osasuna             76
# Espanyol            76
# Elche               76
# Cadiz               76
# Rayo Vallecano      38
# Huesca              38
# Leganes             38
# Valladolid          38
# Name: team, dtype: int64

# %%
matches[matches["team"] == "Alaves"].sort_values("date")
# Out:
#       Unnamed: 0        date   time     comp         round  day venue result  \
# 1254           0  2019-08-18  17:00  La Liga   Matchweek 1  Sun  Home      W
# 1255           1  2019-08-25  17:00  La Liga   Matchweek 2  Sun  Home      D
# 1256           2  2019-08-31  19:00  La Liga   Matchweek 3  Sat  Away      D
# 1257           3  2019-09-15  14:00  La Liga   Matchweek 4  Sun  Home      L
# 1258           4  2019-09-22  18:30  La Liga   Matchweek 5  Sun  Away      L
# ...          ...         ...    ...      ...           ...  ...   ...    ...
# 33            35  2022-04-30  14:00  La Liga  Matchweek 34  Sat  Home      W
# 34            36  2022-05-07  18:30  La Liga  Matchweek 35  Sat  Away      L
# 35            37  2022-05-11  19:00  La Liga  Matchweek 36  Wed  Home      W
# 36            38  2022-05-15  19:30  La Liga  Matchweek 37  Sun  Away      L
# 37            39  2022-05-22  20:00  La Liga  Matchweek 38  Sun  Home      L
#
# ...

# %%
matches.dtypes
# Out:
# Unnamed: 0        int64
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk                int64
# pkatt             int64
# season            int64
# team             object
# dtype: object

# %%
del matches["comp"]
del matches["notes"]

# %%
matches["date"] = pd.to_datetime(matches["date"])
matches["target"] = (matches["result"] == "W").astype("int")
matches
# Out:
#       Unnamed: 0       date   time         round  day venue result   gf   ga  \
# 0              0 2021-08-14  22:00   Matchweek 1  Sat  Home      L  1.0  4.0
# 1              1 2021-08-21  17:00   Matchweek 2  Sat  Home      L  0.0  1.0
# 2              2 2021-08-27  22:15   Matchweek 3  Fri  Away      L  0.0  3.0
# 3              3 2021-09-18  21:00   Matchweek 5  Sat  Home      L  0.0  2.0
# 4              4 2021-09-22  19:30   Matchweek 6  Wed  Away      L  0.0  1.0
# ...          ...        ...    ...           ...  ...   ...    ...  ...  ...
# 2009          36 2020-07-05  22:00  Matchweek 34  Sun  Home      L  1.0  4.0
# 2010          37 2020-07-08  20:30  Matchweek 35  Wed  Away      W  3.0  1.0
# 2011          38 2020-07-13  19:30  Matchweek 36  Mon  Home      L  1.0  2.0
# 2012          39 2020-07-16  21:00  Matchweek 37  Thu  Away      L  1.0  2.0
# 2013          40 2020-07-19  18:30  Matchweek 38  Sun  Home      W  4.0  0.0
#
# ...

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes
matches["opp_code"] = matches["opponent"].astype("category").cat.codes
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")
matches["day_code"] = matches["date"].dt.dayofweek
matches
# Out:
#       Unnamed: 0       date   time         round  day venue result   gf   ga  \
# 0              0 2021-08-14  22:00   Matchweek 1  Sat  Home      L  1.0  4.0
# 1              1 2021-08-21  17:00   Matchweek 2  Sat  Home      L  0.0  1.0
# 2              2 2021-08-27  22:15   Matchweek 3  Fri  Away      L  0.0  3.0
# 3              3 2021-09-18  21:00   Matchweek 5  Sat  Home      L  0.0  2.0
# 4              4 2021-09-22  19:30   Matchweek 6  Wed  Away      L  0.0  1.0
# ...          ...        ...    ...           ...  ...   ...    ...  ...  ...
# 2009          36 2020-07-05  22:00  Matchweek 34  Sun  Home      L  1.0  4.0
# 2010          37 2020-07-08  20:30  Matchweek 35  Wed  Away      W  3.0  1.0
# 2011          38 2020-07-13  19:30  Matchweek 36  Mon  Home      L  1.0  2.0
# 2012          39 2020-07-16  21:00  Matchweek 37  Thu  Away      L  1.0  2.0
# 2013          40 2020-07-19  18:30  Matchweek 38  Sun  Home      W  4.0  0.0
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)
train = matches[matches["date"] < '2021-01-01']
test = matches[matches["date"] > '2021-01-01']
predictors = ["venue_code", "opp_code", "hour", "day_code"]
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])
preds
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score
error = accuracy_score(test["target"], preds)
error
# Out:
# 0.6385199240986718

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0    1
# actual
# 0          575  112
# 1          269   98

# %%
from sklearn.metrics import precision_score
precision_score(test["target"], preds)
# Out:
# 0.4666666666666667

# %%
grouped_matches = matches.groupby("team")
group = grouped_matches.get_group("Alaves").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]
rolling_averages(group, cols, new_cols)
# Out:
#       Unnamed: 0       date   time         round  day venue result   gf   ga  \
# 1257           3 2019-09-15  14:00   Matchweek 4  Sun  Home      L  0.0  1.0
# 1258           4 2019-09-22  18:30   Matchweek 5  Sun  Away      L  0.0  2.0
# 1259           5 2019-09-26  21:00   Matchweek 6  Thu  Away      L  0.0  3.0
# 1260           6 2019-09-29  16:00   Matchweek 7  Sun  Home      W  2.0  0.0
# 1261           7 2019-10-05  18:30   Matchweek 8  Sat  Away      L  1.0  2.0
# ...          ...        ...    ...           ...  ...   ...    ...  ...  ...
# 33            35 2022-04-30  14:00  Matchweek 34  Sat  Home      W  2.0  1.0
# 34            36 2022-05-07  18:30  Matchweek 35  Sat  Away      L  0.0  4.0
# 35            37 2022-05-11  19:00  Matchweek 36  Wed  Home      W  2.0  1.0
# 36            38 2022-05-15  19:30  Matchweek 37  Sun  Away      L  1.0  3.0
# 37            39 2022-05-22  20:00  Matchweek 38  Sun  Home      L  0.0  1.0
#
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rolling
# Out:
#                  Unnamed: 0       date   time         round  day venue result  \
# team
# Alaves     1257           3 2019-09-15  14:00   Matchweek 4  Sun  Home      L
#            1258           4 2019-09-22  18:30   Matchweek 5  Sun  Away      L
#            1259           5 2019-09-26  21:00   Matchweek 6  Thu  Away      L
#            1260           6 2019-09-29  16:00   Matchweek 7  Sun  Home      W
#            1261           7 2019-10-05  18:30   Matchweek 8  Sat  Away      L
# ...                     ...        ...    ...           ...  ...   ...    ...
# Villarreal 755           48 2022-04-30  14:00  Matchweek 34  Sat  Away      L
#            756           50 2022-05-08  16:15  Matchweek 35  Sun  Home      D
#            757           51 2022-05-12  20:00  Matchweek 36  Thu  Away      W
#            758           52 2022-05-15  19:30  Matchweek 37  Sun  Home      L
#            759           53 2022-05-22  22:00  Matchweek 38  Sun  Away      W
#
# ...

# %%
matches_rolling = matches_rolling.droplevel('team')
matches_rolling
# Out:
#       Unnamed: 0       date   time         round  day venue result   gf   ga  \
# 1257           3 2019-09-15  14:00   Matchweek 4  Sun  Home      L  0.0  1.0
# 1258           4 2019-09-22  18:30   Matchweek 5  Sun  Away      L  0.0  2.0
# 1259           5 2019-09-26  21:00   Matchweek 6  Thu  Away      L  0.0  3.0
# 1260           6 2019-09-29  16:00   Matchweek 7  Sun  Home      W  2.0  0.0
# 1261           7 2019-10-05  18:30   Matchweek 8  Sat  Away      L  1.0  2.0
# ...          ...        ...    ...           ...  ...   ...    ...  ...  ...
# 755           48 2022-04-30  14:00  Matchweek 34  Sat  Away      L  1.0  2.0
# 756           50 2022-05-08  16:15  Matchweek 35  Sun  Home      D  1.0  1.0
# 757           51 2022-05-12  20:00  Matchweek 36  Thu  Away      W  5.0  1.0
# 758           52 2022-05-15  19:30  Matchweek 37  Sun  Home      L  1.0  2.0
# 759           53 2022-05-22  22:00  Matchweek 38  Sun  Away      W  2.0  0.0
#
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2021-01-01']
    test = data[data["date"] > '2021-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)
error
# Out:
# 0.514792899408284

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
combined.tail(10)
# Out:
#       actual  predicted       date        team        opponent result
# 1926       0          0 2022-03-20  Villarreal           Cádiz      L
# 1927       0          0 2022-04-02  Villarreal         Levante      L
# 1928       0          0 2022-04-09  Villarreal   Athletic Club      D
# 1929       1          0 2022-04-16  Villarreal          Getafe      W
# 1930       1          0 2022-04-19  Villarreal        Valencia      W
# 1931       0          0 2022-04-30  Villarreal          Alavés      L
# 1932       0          0 2022-05-08  Villarreal         Sevilla      D
# 1933       1          0 2022-05-12  Villarreal  Rayo Vallecano      W
# 1934       0          0 2022-05-15  Villarreal   Real Sociedad      L
# 1935       1          0 2022-05-22  Villarreal       Barcelona      W

# %%
merged = combined.merge(combined, left_on=["date", "team"], right_on=["date", "opponent"])
merged
# Out:
#      actual_x  predicted_x       date         team_x      opponent_x result_x  \
# 0           1            1 2021-01-03  Athletic Club           Elche        W
# 1           0            0 2021-01-06  Athletic Club       Barcelona        L
# 2           1            0 2021-01-25  Athletic Club          Getafe        W
# 3           0            0 2021-01-31  Athletic Club       Barcelona        L
# 4           1            0 2021-02-15  Athletic Club           Cádiz        W
# ..        ...          ...        ...            ...             ...      ...
# 721         0            0 2022-04-30     Villarreal          Alavés        L
# 722         0            0 2022-05-08     Villarreal         Sevilla        D
# 723         1            0 2022-05-12     Villarreal  Rayo Vallecano        W
# 724         0            0 2022-05-15     Villarreal   Real Sociedad        L
# 725         1            0 2022-05-22     Villarreal       Barcelona        W
#
# ...

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# 1    63
# 0    60
# Name: actual_x, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(min_samples_split=10, random_state=69)
dt.fit(train[predictors], train["target"])
# Out:
# DecisionTreeClassifier(min_samples_split=10, random_state=69)

# %%
preds1 = dt.predict(test[predictors])
preds1
# Out:
# array([0, 1, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import accuracy_score
error1 = accuracy_score(test["target"], preds1)
error1
# Out:
# 0.610056925996205

# %%
combined1 = pd.DataFrame(dict(actual=test["target"], predicted=preds1))
pd.crosstab(index=combined1["actual"], columns=combined1["predicted"])
# Out:
# predicted    0    1
# actual
# 0          530  157
# 1          254  113

# %%
from sklearn.metrics import precision_score
precision_score(test["target"], preds1)
# Out:
# 0.4185185185185185

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2021-01-01']
    test = data[data["date"] > '2021-01-01']
    dt.fit(train[predictors], train["target"])
    preds1 = dt.predict(test[predictors])
    combined1 = pd.DataFrame(dict(actual=test["target"], predicted=preds1), index=test.index)
    error1 = precision_score(test["target"], preds1)
    return combined1, error1

# %%
combined1, error1 = make_predictions(matches_rolling, predictors + new_cols)
error1
# Out:
# 0.37910447761194027

# %%
combined1 = combined1.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
combined1.tail(10)
# Out:
#       actual  predicted       date        team        opponent result
# 1926       0          0 2022-03-20  Villarreal           Cádiz      L
# 1927       0          0 2022-04-02  Villarreal         Levante      L
# 1928       0          1 2022-04-09  Villarreal   Athletic Club      D
# 1929       1          0 2022-04-16  Villarreal          Getafe      W
# 1930       1          0 2022-04-19  Villarreal        Valencia      W
# 1931       0          0 2022-04-30  Villarreal          Alavés      L
# 1932       0          0 2022-05-08  Villarreal         Sevilla      D
# 1933       1          0 2022-05-12  Villarreal  Rayo Vallecano      W
# 1934       0          1 2022-05-15  Villarreal   Real Sociedad      L
# 1935       1          0 2022-05-22  Villarreal       Barcelona      W

# %%
merged1 = combined1.merge(combined1, left_on=["date", "team"], right_on=["date", "opponent"])
merged1
# Out:
#      actual_x  predicted_x       date         team_x      opponent_x result_x  \
# 0           1            0 2021-01-03  Athletic Club           Elche        W
# 1           0            0 2021-01-06  Athletic Club       Barcelona        L
# 2           1            0 2021-01-25  Athletic Club          Getafe        W
# 3           0            0 2021-01-31  Athletic Club       Barcelona        L
# 4           1            1 2021-02-15  Athletic Club           Cádiz        W
# ..        ...          ...        ...            ...             ...      ...
# 721         0            0 2022-04-30     Villarreal          Alavés        L
# 722         0            0 2022-05-08     Villarreal         Sevilla        D
# 723         1            0 2022-05-12     Villarreal  Rayo Vallecano        W
# 724         0            1 2022-05-15     Villarreal   Real Sociedad        L
# 725         1            0 2022-05-22     Villarreal       Barcelona        W
#
# ...

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=69)

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2021-01-01']
    test = data[data["date"] > '2021-01-01']
    gb.fit(train[predictors], train["target"])
    preds2 = gb.predict(test[predictors])
    combined2 = pd.DataFrame(dict(actual=test["target"], predicted=preds2), index=test.index)
    error2 = precision_score(test["target"], preds2)
    return combined2, error2

# %%
combined2, error2 = make_predictions(matches_rolling, predictors + new_cols)
error2
# Out:
# 0.5728643216080402

# %%
combined2 = combined2.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
combined2.tail(10)
# Out:
#       actual  predicted       date        team        opponent result
# 1926       0          0 2022-03-20  Villarreal           Cádiz      L
# 1927       0          0 2022-04-02  Villarreal         Levante      L
# 1928       0          0 2022-04-09  Villarreal   Athletic Club      D
# 1929       1          0 2022-04-16  Villarreal          Getafe      W
# 1930       1          0 2022-04-19  Villarreal        Valencia      W
# 1931       0          0 2022-04-30  Villarreal          Alavés      L
# 1932       0          0 2022-05-08  Villarreal         Sevilla      D
# 1933       1          0 2022-05-12  Villarreal  Rayo Vallecano      W
# 1934       0          0 2022-05-15  Villarreal   Real Sociedad      L
# 1935       1          0 2022-05-22  Villarreal       Barcelona      W

# %%
merged2 = combined2.merge(combined2, left_on=["date", "team"], right_on=["date", "opponent"])
merged2
# Out:
#      actual_x  predicted_x       date         team_x      opponent_x result_x  \
# 0           1            0 2021-01-03  Athletic Club           Elche        W
# 1           0            0 2021-01-06  Athletic Club       Barcelona        L
# 2           1            0 2021-01-25  Athletic Club          Getafe        W
# 3           0            0 2021-01-31  Athletic Club       Barcelona        L
# 4           1            0 2021-02-15  Athletic Club           Cádiz        W
# ..        ...          ...        ...            ...             ...      ...
# 721         0            0 2022-04-30     Villarreal          Alavés        L
# 722         0            0 2022-05-08     Villarreal         Sevilla        D
# 723         1            0 2022-05-12     Villarreal  Rayo Vallecano        W
# 724         0            0 2022-05-15     Villarreal   Real Sociedad        L
# 725         1            0 2022-05-22     Villarreal       Barcelona        W
#
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2021-01-01']
    test = data[data["date"] > '2021-01-01']
    knn.fit(train[predictors], train["target"])
    preds3 = knn.predict(test[predictors])
    combined3 = pd.DataFrame(dict(actual=test["target"], predicted=preds3), index=test.index)
    error3 = precision_score(test["target"], preds3)
    return combined3, error3

# %%
combined3, error3 = make_predictions(matches_rolling, predictors + new_cols)
error3
# Out:
# 0.3937007874015748

# %%
combined3 = combined3.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
combined3.tail(10)
# Out:
#       actual  predicted       date        team        opponent result
# 1926       0          1 2022-03-20  Villarreal           Cádiz      L
# 1927       0          0 2022-04-02  Villarreal         Levante      L
# 1928       0          0 2022-04-09  Villarreal   Athletic Club      D
# 1929       1          1 2022-04-16  Villarreal          Getafe      W
# 1930       1          0 2022-04-19  Villarreal        Valencia      W
# 1931       0          0 2022-04-30  Villarreal          Alavés      L
# 1932       0          0 2022-05-08  Villarreal         Sevilla      D
# 1933       1          0 2022-05-12  Villarreal  Rayo Vallecano      W
# 1934       0          0 2022-05-15  Villarreal   Real Sociedad      L
# 1935       1          0 2022-05-22  Villarreal       Barcelona      W

# %%
merged3 = combined3.merge(combined3, left_on=["date", "team"], right_on=["date", "opponent"])
merged3
# Out:
#      actual_x  predicted_x       date         team_x      opponent_x result_x  \
# 0           1            0 2021-01-03  Athletic Club           Elche        W
# 1           0            0 2021-01-06  Athletic Club       Barcelona        L
# 2           1            0 2021-01-25  Athletic Club          Getafe        W
# 3           0            0 2021-01-31  Athletic Club       Barcelona        L
# 4           1            0 2021-02-15  Athletic Club           Cádiz        W
# ..        ...          ...        ...            ...             ...      ...
# 721         0            0 2022-04-30     Villarreal          Alavés        L
# 722         0            0 2022-05-08     Villarreal         Sevilla        D
# 723         1            0 2022-05-12     Villarreal  Rayo Vallecano        W
# 724         0            0 2022-05-15     Villarreal   Real Sociedad        L
# 725         1            0 2022-05-22     Villarreal       Barcelona        W
#
# ...
