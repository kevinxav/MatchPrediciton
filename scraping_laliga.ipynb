# %%
import requests

# %%
url1="https://fbref.com/en/comps/12/2020-2021/stats/2020-2021-La-Liga-Stats"

# %%
data=requests.get(url1)
data.text
# Out:
# '    \n      \n<!DOCTYPE html>\n<html data-version="klecko-" data-root="/home/fb/deploy/www/base" lang="en" class="no-js" >\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="x-ua-compatible" content="ie=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />\n    <link rel="dns-prefetch" href="https://cdn.ssref.net/req/202301181" />\n<!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->\n<script type="text/javascript" async=true>\n    (function() {\n\tvar host = window.location.hostname;\n\tvar element = document.createElement(\'script\');\n\tvar firstScript = document.getElementsByTagName(\'script\')[0];\n\tvar url = \'https://cmp.quantcast.com\'\n\t    .concat(\'/choice/\', \'XwNYEpNeFfhfr\', \'/\', host, \n\t\t    \'/choice.js?tag_version=V2\');\n\tvar uspTries = 0;\n\tvar uspTriesLimit = 3;\n\telement.async = true;\n\telement.type = \'text/javascript\';\n\telement.src = url;\n\t\n\tfirstScript.parentNode.insertBefore(element, firstScript);\n\t\n\tfunction makeStub() {\n\t    var TCF_LOCATOR_NAME = \'__tcfapiLocator\';\n\t    var queue = [];\n\t    var win = window;\n\t    var cmpFrame;\n\t    \n\t    function addFrame() {\n\t\tvar doc = win.document;\n\t\tvar otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);\n\t\t\n\t\tif (!otherCMP) {\n\t\t    if (doc.body) {\n\t\t\tvar iframe = doc.createElement(\'iframe\');\n\t\t\t\n\t\t\tiframe.style.cssText = \'display:none\';\n\t\t\tiframe.name = TCF_LOCATOR_NAME;\n\t\t\tdoc.body.appendChild(iframe);\n\t\t    } else {\n\t\t\tsetTimeout(addFrame, 5);\n\t\t    }\n\t\t}\n\t\treturn !otherCMP;\n\t    }\n\t    \n\t    function tcfAPIHandler() {\n\t\tvar gdprApplies;\n\t\tvar args = arguments;\n\t\t\n\t\tif (!args.length) {\n\t\t    return queue;\n\t\t} else if (args[0] === \'setGdprApplies\') {\n\t\t    if (\n\t\t\targs.length > 3 &&\n\t\t\t    args[2] === 2 &&\n\t\t\t    typeof args[3] === \'boolean\'\n\t\t    ) {\n\t\t\tgdprApplies = args[3];\n\t\t\tif (typeof args[2] === \'function\') {\n\t\t\t    args[2](\'set\', true);\n\t\t\t}\n\t\t    }\n\t\t} else if (args[0] === \'ping\') {\n\t\t    var retr = {\n\t\t\tgdprApplies: gdprApplies,\n\t\t\tcmpLoaded: false,\n\t\t\tcmpStatus: \'stub\'\n\t\t    };\n\t\t    \n\t\t    if (typeof args[2] === \'function\') {\n\t\t\targs[2](retr);\n\t\t    }\n\t\t} else {\n\t\t    if(args[0] === \'init\' && typeof args[3] === \'object\') {\n\t\t\targs[3] = Object.assign(args[3], { tag_version: \'V2\' });\n\t\t    }\n\t\t    queue.push(args);\n\t\t}\n\t    }\n\t    \n\t    function postMessageEventHandler(event) {\n\t\tvar msgIsString = typeof event.data === \'string\';\n\t\tvar json = {};\n\t\t\n\t\ttry {\n\t\t    if (msgIsString) {\n\t\t\tjson = JSON.parse(event.data);\n\t\t    } else {\n\t\t\tjson = event.data;\n\t\t    }\n\t\t} catch (ignore) {}\n\t\t\n\t\tvar payload = json.__tcfapiCall;\n\t\t\n\t\tif (payload) {\n\t\t    window.__tcfapi(\n\t\t\tpayload.command,\n\t\t\tpayload.version,\n\t\t\tfunction(retValue, success) {\n\t\t\t    var returnMsg = {\n\t\t\t\t__tcfapiReturn: {\n\t\t\t\t    returnValue: retValue,\n\t\t\t\t    success: success,\n\t\t\t\t    callId: payload.callId\n\t\t\t\t}\n\t\t\t    };\n\t\t\t    if (msgIsString) {\n\t\t\t\treturnMsg = JSON.stringify(returnMsg);\n\t\t\t    }\n\t\t\t    if (event && event.source && event.source.postMessage) {\n\t\t\t\tevent.source.postMessage(returnMsg, \'*\');\n\t\t\t    }\n\t\t\t},\n\t\t\tpayload.parameter\n\t\t    );\n\t\t}\n\t    }\n\t    \n\t    while (win) {\n\t\ttry {\n\t\t    if (win.frames[TCF_LOCATOR_NAME]) {\n\t\t\tcmpFrame = win;\n\t\t\tbreak;\n\t\t    }\n\t\t} catch (ignore) {}\n\t\t\n\t\tif (win === window.top) {\n\t\t    break;\n\t\t}\n\t\twin = win.parent;\n\t    }\n\t    if (!cmpFrame) {\n\t\taddFrame();\n\t\twin.__tcfapi = tcfAPIHandler;\n\t\twin.addEventListener(\'message\', postMessageEventHandler, false);\n\t    }\n\t};\n\t\n\tmakeStub();\n\t\n\tvar uspStubFunction = function() {\n\t    var arg = arguments;\n\t    if (typ ...

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(data.text)

# %%
table_standings=soup.select('table.stats_table')[0]

# %%
table_standings
# Out:
# <table class="stats_table sortable min_width" data-cols-to-freeze=",1" id="stats_squads_standard_for"> <caption>Squad Standard Stats <span style="color: #666; font-size:smaller">2020-2021 La Liga</span> Table</caption> <colgroup><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/><col/></colgroup> <thead> <tr class="over_header"> <th aria-label="" class="over_header center" colspan="4" data-stat=""></th> <th aria-label="" class="over_header center group_start" colspan="4" data-stat="header_playing">Playing Time</th> <th aria-label="" class="over_header center group_start" colspan="8" data-stat="header_performance">Performance</th> <th aria-label="" class="over_header center group_start" colspan="4" data-stat="header_expected">Expected</th> <th aria-label="" class="over_header center group_start" colspan="2" data-stat="header_progression">Progression</th> <th aria-label="" class="over_header center group_start" colspan="10" data-stat="header_per90">Per 90 Minutes</th> </tr> <tr> <th aria-label="Squad" class="poptip sort_default_asc center" data-stat="team" scope="col">Squad</th> <th aria-label="# of Players" class="poptip center" data-stat="players_used" data-tip="&lt;strong&gt;# of Players&lt;/strong&gt;&lt;br&gt;Number of Players used in Games" scope="col"># Pl</th> <th aria-label="Average Age" class="poptip sort_default_asc center" data-stat="avg_age" data-tip="&lt;strong&gt;Average Age&lt;/strong&gt;&lt;br&gt;Age is weighted by minutes played" scope="col">Age</th> <th aria-label="Possession" class="poptip center" data-stat="possession" data-tip="&lt;strong&gt;Possession&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;Possession&lt;/strong&gt;&lt;br&gt;Calculated as the percentage of passes attempted" scope="col">Poss</th> <th aria-label="Matches Played" class="poptip center group_start" data-over-header="Playing Time" data-stat="games" data-tip="&lt;strong&gt;Matches Played&lt;/strong&gt;&lt;br&gt;Matches Played by the player or squad" scope="col">MP</th> <th aria-label="Starts" class="poptip center" data-over-header="Playing Time" data-stat="games_starts" data-tip="Game or games started by player" scope="col">Starts</th> <th aria-label="Minutes" class="poptip center" data-over-header="Playing Time" data-stat="minutes" data-tip="&lt;strong&gt;Minutes&lt;/strong&gt;&lt;br&gt;" scope="col">Min</th> <th aria-label="90s Played" class="poptip center" data-over-header="Playing Time" data-stat="minutes_90s" data-tip="&lt;strong&gt;90s Played&lt;/strong&gt;&lt;br&gt;&lt;strong&gt;90s played&lt;/strong&gt;&lt;br&gt;Minutes played divided by 90" scope="col">90s</th> <th aria-label="Goals" class="poptip center group_start" data-over-header="Performance" data-stat="goals" data-tip="&lt;strong&gt;Goals&lt;/strong&gt;&lt;br&gt;Goals scored or allowed" scope="col">Gls</th> <th aria-label="Assists" class="poptip center" data-over-header="Performance" data-stat="assists" data-tip="&lt;strong&gt;Assists&lt;/strong&gt;&lt;br&gt;Assists" scope="col">Ast</th> <th aria-label="Goals + Assists" class="poptip center" data-over-header="Performance" data-stat="goals_assists" data-tip="&lt;strong&gt;Goals + Assists&lt;/strong&gt;&lt;br&gt;Goals and Assists" scope="col">G+A</th> <th aria-label="Non-Penalty Goals" class="poptip center" data-over-header="Performance" data-stat="goals_pens" data-tip="&lt;strong&gt;Non-Penalty Goals&lt;/strong&gt;&lt;br&gt;Non-Penalty Goals" scope="col">G-PK</th> <th aria-label="Penalty Kicks Made" class="poptip center" data-over-header="Performance" data-stat="pens_made" data-tip="&lt;strong&gt;Penalty Kicks Made&lt;/strong&gt;&lt;br&gt;Penalty Kicks Made" scope="col">PK</th> <th aria-label="Penalty Kicks Attempted" class="poptip center" data-over-header="Performance" data-stat="pens_att" data-tip="&lt;strong&gt;Penalty Kicks Attempted&lt;/strong&gt;&lt;br&gt;Penalty Kicks Attempted" scope="col">PKat ...

# %%
links = table_standings.find_all('a')
links = [l.get("href") for l in links]

# %%
links = [l for l in links if '/squads/' in l]
print(links)
# Out:
# ['/en/squads/8d6fd021/2020-2021/Alaves-Stats', '/en/squads/2b390eca/2020-2021/Athletic-Club-Stats', '/en/squads/db3b9613/2020-2021/Atletico-Madrid-Stats', '/en/squads/206d90db/2020-2021/Barcelona-Stats', '/en/squads/fc536746/2020-2021/Real-Betis-Stats', '/en/squads/ee7c297c/2020-2021/Cadiz-Stats', '/en/squads/f25da7fb/2020-2021/Celta-Vigo-Stats', '/en/squads/bea5c710/2020-2021/Eibar-Stats', '/en/squads/6c8b07df/2020-2021/Elche-Stats', '/en/squads/7848bd64/2020-2021/Getafe-Stats', '/en/squads/a0435291/2020-2021/Granada-Stats', '/en/squads/c6c493e6/2020-2021/Huesca-Stats', '/en/squads/9800b6a1/2020-2021/Levante-Stats', '/en/squads/03c57e2b/2020-2021/Osasuna-Stats', '/en/squads/53a2f082/2020-2021/Real-Madrid-Stats', '/en/squads/e31d1cd9/2020-2021/Real-Sociedad-Stats', '/en/squads/ad2be733/2020-2021/Sevilla-Stats', '/en/squads/dcc91a7b/2020-2021/Valencia-Stats', '/en/squads/17859612/2020-2021/Valladolid-Stats', '/en/squads/2a8183b3/2020-2021/Villarreal-Stats']

# %%
team_urls = [f"https://fbref.com{l}" for l in links]
team_urls#these are absolute links
# Out:
# ['https://fbref.com/en/squads/8d6fd021/2020-2021/Alaves-Stats',
#  'https://fbref.com/en/squads/2b390eca/2020-2021/Athletic-Club-Stats',
#  'https://fbref.com/en/squads/db3b9613/2020-2021/Atletico-Madrid-Stats',
#  'https://fbref.com/en/squads/206d90db/2020-2021/Barcelona-Stats',
#  'https://fbref.com/en/squads/fc536746/2020-2021/Real-Betis-Stats',
#  'https://fbref.com/en/squads/ee7c297c/2020-2021/Cadiz-Stats',
#  'https://fbref.com/en/squads/f25da7fb/2020-2021/Celta-Vigo-Stats',
#  'https://fbref.com/en/squads/bea5c710/2020-2021/Eibar-Stats',
#  'https://fbref.com/en/squads/6c8b07df/2020-2021/Elche-Stats',
#  'https://fbref.com/en/squads/7848bd64/2020-2021/Getafe-Stats',
#  'https://fbref.com/en/squads/a0435291/2020-2021/Granada-Stats',
#  'https://fbref.com/en/squads/c6c493e6/2020-2021/Huesca-Stats',
#  'https://fbref.com/en/squads/9800b6a1/2020-2021/Levante-Stats',
#  'https://fbref.com/en/squads/03c57e2b/2020-2021/Osasuna-Stats',
#  'https://fbref.com/en/squads/53a2f082/2020-2021/Real-Madrid-Stats',
#  'https://fbref.com/en/squads/e31d1cd9/2020-2021/Real-Sociedad-Stats',
#  'https://fbref.com/en/squads/ad2be733/2020-2021/Sevilla-Stats',
#  'https://fbref.com/en/squads/dcc91a7b/2020-2021/Valencia-Stats',
#  'https://fbref.com/en/squads/17859612/2020-2021/Valladolid-Stats',
#  'https://fbref.com/en/squads/2a8183b3/2020-2021/Villarreal-Stats']

# %%
team_url=team_urls[0]

# %%
data=requests.get(team_url)
data.text
# Out:
# '    \n      \n<!DOCTYPE html>\n<html data-version="klecko-" data-root="/home/fb/deploy/www/base" lang="en" class="no-js" >\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="x-ua-compatible" content="ie=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=2.0" />\n    <link rel="dns-prefetch" href="https://cdn.ssref.net/req/202301181" />\n<!-- Quantcast Choice. Consent Manager Tag v2.0 (for TCF 2.0) -->\n<script type="text/javascript" async=true>\n    (function() {\n\tvar host = window.location.hostname;\n\tvar element = document.createElement(\'script\');\n\tvar firstScript = document.getElementsByTagName(\'script\')[0];\n\tvar url = \'https://cmp.quantcast.com\'\n\t    .concat(\'/choice/\', \'XwNYEpNeFfhfr\', \'/\', host, \n\t\t    \'/choice.js?tag_version=V2\');\n\tvar uspTries = 0;\n\tvar uspTriesLimit = 3;\n\telement.async = true;\n\telement.type = \'text/javascript\';\n\telement.src = url;\n\t\n\tfirstScript.parentNode.insertBefore(element, firstScript);\n\t\n\tfunction makeStub() {\n\t    var TCF_LOCATOR_NAME = \'__tcfapiLocator\';\n\t    var queue = [];\n\t    var win = window;\n\t    var cmpFrame;\n\t    \n\t    function addFrame() {\n\t\tvar doc = win.document;\n\t\tvar otherCMP = !!(win.frames[TCF_LOCATOR_NAME]);\n\t\t\n\t\tif (!otherCMP) {\n\t\t    if (doc.body) {\n\t\t\tvar iframe = doc.createElement(\'iframe\');\n\t\t\t\n\t\t\tiframe.style.cssText = \'display:none\';\n\t\t\tiframe.name = TCF_LOCATOR_NAME;\n\t\t\tdoc.body.appendChild(iframe);\n\t\t    } else {\n\t\t\tsetTimeout(addFrame, 5);\n\t\t    }\n\t\t}\n\t\treturn !otherCMP;\n\t    }\n\t    \n\t    function tcfAPIHandler() {\n\t\tvar gdprApplies;\n\t\tvar args = arguments;\n\t\t\n\t\tif (!args.length) {\n\t\t    return queue;\n\t\t} else if (args[0] === \'setGdprApplies\') {\n\t\t    if (\n\t\t\targs.length > 3 &&\n\t\t\t    args[2] === 2 &&\n\t\t\t    typeof args[3] === \'boolean\'\n\t\t    ) {\n\t\t\tgdprApplies = args[3];\n\t\t\tif (typeof args[2] === \'function\') {\n\t\t\t    args[2](\'set\', true);\n\t\t\t}\n\t\t    }\n\t\t} else if (args[0] === \'ping\') {\n\t\t    var retr = {\n\t\t\tgdprApplies: gdprApplies,\n\t\t\tcmpLoaded: false,\n\t\t\tcmpStatus: \'stub\'\n\t\t    };\n\t\t    \n\t\t    if (typeof args[2] === \'function\') {\n\t\t\targs[2](retr);\n\t\t    }\n\t\t} else {\n\t\t    if(args[0] === \'init\' && typeof args[3] === \'object\') {\n\t\t\targs[3] = Object.assign(args[3], { tag_version: \'V2\' });\n\t\t    }\n\t\t    queue.push(args);\n\t\t}\n\t    }\n\t    \n\t    function postMessageEventHandler(event) {\n\t\tvar msgIsString = typeof event.data === \'string\';\n\t\tvar json = {};\n\t\t\n\t\ttry {\n\t\t    if (msgIsString) {\n\t\t\tjson = JSON.parse(event.data);\n\t\t    } else {\n\t\t\tjson = event.data;\n\t\t    }\n\t\t} catch (ignore) {}\n\t\t\n\t\tvar payload = json.__tcfapiCall;\n\t\t\n\t\tif (payload) {\n\t\t    window.__tcfapi(\n\t\t\tpayload.command,\n\t\t\tpayload.version,\n\t\t\tfunction(retValue, success) {\n\t\t\t    var returnMsg = {\n\t\t\t\t__tcfapiReturn: {\n\t\t\t\t    returnValue: retValue,\n\t\t\t\t    success: success,\n\t\t\t\t    callId: payload.callId\n\t\t\t\t}\n\t\t\t    };\n\t\t\t    if (msgIsString) {\n\t\t\t\treturnMsg = JSON.stringify(returnMsg);\n\t\t\t    }\n\t\t\t    if (event && event.source && event.source.postMessage) {\n\t\t\t\tevent.source.postMessage(returnMsg, \'*\');\n\t\t\t    }\n\t\t\t},\n\t\t\tpayload.parameter\n\t\t    );\n\t\t}\n\t    }\n\t    \n\t    while (win) {\n\t\ttry {\n\t\t    if (win.frames[TCF_LOCATOR_NAME]) {\n\t\t\tcmpFrame = win;\n\t\t\tbreak;\n\t\t    }\n\t\t} catch (ignore) {}\n\t\t\n\t\tif (win === window.top) {\n\t\t    break;\n\t\t}\n\t\twin = win.parent;\n\t    }\n\t    if (!cmpFrame) {\n\t\taddFrame();\n\t\twin.__tcfapi = tcfAPIHandler;\n\t\twin.addEventListener(\'message\', postMessageEventHandler, false);\n\t    }\n\t};\n\t\n\tmakeStub();\n\t\n\tvar uspStubFunction = function() {\n\t    var arg = arguments;\n\t    if (typ ...

# %%
import pandas as pd
matches = pd.read_html(data.text, match="Scores & Fixtures",header=None)
matches[0]
# Out:
#           Date   Time          Comp         Round  Day Venue Result  GF  GA  \
# 0   2020-09-13  14:00       La Liga   Matchweek 1  Sun  Home      L   0   1
# 1   2020-09-20  18:30       La Liga   Matchweek 2  Sun  Away      L   1   2
# 2   2020-09-26  13:00       La Liga   Matchweek 3  Sat  Home      D   0   0
# 3   2020-09-30  19:00       La Liga   Matchweek 4  Wed  Away      L   1   3
# 4   2020-10-04  14:00       La Liga   Matchweek 5  Sun  Home      W   1   0
# 5   2020-10-18  18:30       La Liga   Matchweek 6  Sun  Home      L   0   2
# 6   2020-10-25  14:00       La Liga   Matchweek 7  Sun  Away      W   2   0
# 7   2020-10-31  21:00       La Liga   Matchweek 8  Sat  Home      D   1   1
# 8   2020-11-08  18:30       La Liga   Matchweek 9  Sun  Away      D   1   1
# 9   2020-11-22  21:00       La Liga  Matchweek 10  Sun  Home      D   2   2
# 10  2020-11-28  21:00       La Liga  Matchweek 11  Sat  Away      W   2   1
# 11  2020-12-06  21:00       La Liga  Matchweek 12  Sun  Home      D   0   0
# 12  2020-12-12  18:30       La Liga  Matchweek 13  Sat  Away      L   0   1
# 13  2020-12-16  21:00  Copa del Rey   First round  Wed  Away      W   2   0
# 14  2020-12-20  14:00       La Liga  Matchweek 14  Sun  Away      L   0   2
# 15  2020-12-23  22:00       La Liga  Matchweek 15  Wed  Home      W   2   1
# 16  2020-12-31  16:15       La Liga  Matchweek 16  Thu  Away      D   1   1
# 17  2021-01-03  16:15       La Liga  Matchweek 17  Sun  Home      L   1   2
# 18  2021-01-06  19:00  Copa del Rey  Second round  Wed  Away      W   1   0
# 19  2021-01-10  16:15       La Liga  Matchweek 18  Sun  Away      L   1   3
# 20  2021-01-16  12:00  Copa del Rey   Round of 32  Sat  Away      L   0   5
# 21  2021-01-19  21:30       La Liga  Matchweek 19  Tue  Home      L   1   2
# 22  2021-01-23  21:00       La Liga  Matchweek 20  Sat  Home      L   1   4
# 23  2021-01-31  14:00       La Liga  Matchweek 21  Sun  Away      D   0   0
# 24  2021-02-05  21:00       La Liga  Matchweek 22  Fri  Home      W   1   0
# 25  2021-02-13  21:00       La Liga  Matchweek 23  Sat  Away      L   1   5
# 26  2021-02-21  16:15       La Liga  Matchweek 24  Sun  Away      L   0   4
# 27  2021-02-27  18:30       La Liga  Matchweek 25  Sat  Home      L   0   1
# 28  2021-03-08  21:00       La Liga  Matchweek 26  Mon  Away      L   2   3
# 29  2021-03-13  14:00       La Liga  Matchweek 27  Sat  Home      D   1   1
# 30  2021-03-21  18:30       La Liga  Matchweek 28  Sun  Away      L   0   1
# 31  2021-04-04  14:00       La Liga  Matchweek 29  Sun  Home      L   1   3
# 32  2021-04-10  16:15       La Liga  Matchweek 30  Sat  Away      D   0   0
# 33  2021-04-18  16:15       La Liga  Matchweek 33  Sun  Home      W   1   0
# 34  2021-04-21  21:00       La Liga  Matchweek 31  Wed  Home      W   2   1
# 35  2021-04-24  18:30       La Liga  Matchweek 32  Sat  Away      D   1   1
# 36  2021-05-01  14:00       La Liga  Matchweek 34  Sat  Away      L   0   3
# 37  2021-05-08  14:00       La Liga  Matchweek 35  Sat  Home      D   2   2
# 38  2021-05-11  20:00       La Liga  Matchweek 36  Tue  Away      W   2   0
# 39  2021-05-16  18:30       La Liga  Matchweek 37  Sun  Home      W   4   2
# 40  2021-05-23  21:00       La Liga  Matchweek 38  Sun  Away      L   0   1
#
#            Opponent   xG  xGA  Poss  Attendance               Captain  \
# 0             Betis  1.2  0.4  43.0         NaN      Fernando Pacheco
# 1           Granada  0.7  2.2  44.0         NaN      Fernando Pacheco
# 2            Getafe  1.3  1.1  47.0         NaN      Fernando Pacheco
# 3        Villarreal  1.1  2.3  41.0         NaN      Fernando Pacheco
# 4     Athletic Club  0.6  0.6  41.0         NaN      Fernando Pacheco
# 5             Elche  1.7  0.8  47.0         NaN      Fernando Pacheco
# 6        Valladolid  2.5  0.3  55.0         NaN      Fernando Pacheco
# 7         Barcelona  1.2  1.9  21.0         NaN      Fernando Pacheco
# 8           Levante  0.8  2.1  29.0         NaN      Fernando Pacheco
# 9          Valencia  1.7  1.9  34.0         NaN      Fernando Pacheco
# 10      Real Madrid  2.2  1.7  33.0         NaN      Fernando Pacheco
# 11    Real Sociedad  0.3  1.4  32.0         NaN      Fernando Pacheco
# 12           Huesca  0.2  0.4  34.0         NaN      Fernando Pacheco
# 13        CD Rincón  NaN  NaN   NaN         NaN  Martin Agirregabiria
# 14       Celta Vigo  0.7  1.6  46.0         NaN      Fernando Pacheco
# 15            Eibar  1.9  1.0  44.0         NaN      Fernando Pacheco
# 16          Osasuna  1.6  0.4  67.0         NaN           Manu García
# 17  Atlético Madrid  0.3  2.2  42.0         NaN           Manu García
# 18        La Coruña  NaN  NaN  45.0         NaN           Manu García
# 19            Cádiz  0.9  2.6  60.0         NaN      Fernando Pacheco
# 20          Almería  NaN  NaN  41.0         NaN      Víctor Laguardia
# 21          Sevilla  1.6  1.2  38.0         NaN      Fernando Pacheco
# 22      Real Madrid  0.7  1.4  40.0         NaN      Fernando Pacheco
# 23           Getafe  0.2  0.4  40.0         NaN           Manu García
# 24       Valladolid  1.5  0.1  55.0         NaN           Manu García
# 25        Barcelona  0.7  2.4  27.0         NaN      Fernando Pacheco
# 26    Real Sociedad  0.8  2.4  36.0         NaN           Manu García
# 27          Osasuna  0.4  1.5  53.0         NaN           Manu García
# 28            Betis  0.8  2.0  24.0         NaN           Manu García
# 29            Cádiz  1.5  1.5  51.0         NaN           Manu García
# 30  Atlético Madrid  1.2  0.5  38.0         NaN      Fernando Pacheco
# 31       Celta Vigo  2.0  2.0  54.0         NaN      Fernando Pacheco
# 32    Athletic Club  0.5  1.8  55.0         NaN      Fernando Pacheco
# 33           Huesca  0.4  0.9  51.0         NaN      Fernando Pacheco
# 34       Villarreal  1.7  1.5  33.0         NaN      Fernando Pacheco
# 35         Valencia  1.0  1.0  46.0         NaN      Fernando Pacheco
# 36            Eibar  0.2  1.5  55.0         NaN      Fernando Pacheco
# 37          Levante  1.2  0.8  53.0         NaN      Fernando Pacheco
# 38            Elche  1.6  0.8  33.0         NaN           Manu García
# 39          Granada  2.4  0.8  53.0         NaN      Fernando Pacheco
# 40          Sevilla  1.1  0.4  32.0         NaN           Manu García
#
#    Formation              Referee  Match Report  Notes
# 0    3-1-4-2       Pablo González  Match Report    NaN
# 1      3-5-2     Carlos del Cerro  Match Report    NaN
# 2      4-4-2       Alberola Rojas  Match Report    NaN
# 3      4-4-2          David Medié  Match Report    NaN
# 4      3-5-2         José Sánchez  Match Report    NaN
# 5    3-4-1-2       Adrián Cordero  Match Report    NaN
# 6      4-4-2    José Luis Munuera  Match Report    NaN
# 7    4-1-4-1  Alejandro Hernández  Match Report    NaN
# 8      4-4-2  Isidro Díaz de Mera  Match Report    NaN
# 9      3-5-2       Santiago Jaime  Match Report    NaN
# 10     4-4-2       Adrián Cordero  Match Report    NaN
# 11     4-4-2    José Luis Munuera  Match Report    NaN
# 12     4-4-2         Mario Melero  Match Report    NaN
# 13     4-4-2        Juan Martínez  Match Report    NaN
# 14     4-4-2       Alberola Rojas  Match Report    NaN
# 15     4-4-2     Carlos del Cerro  Match Report    NaN
# 16     4-4-2       Santiago Jaime  Match Report    NaN
# 17     4-5-1        Juan Martínez  Match Report    NaN
# 18     4-4-2       Pablo González  Match Report    NaN
# 19     4-4-2         José Sánchez  Match Report    NaN
# 20   4-2-3-1       Alberola Rojas  Match Report    NaN
# 21     4-4-2  Isidro Díaz de Mera  Match Report    NaN
# 22     4-4-2  Alejandro Hernández  Match Report    NaN
# 23     4-4-2       Santiago Jaime  Match Report    NaN
# 24     4-4-2           César Soto  Match Report    NaN
# 25     4-4-2       Jorge Figueroa  Match Report    NaN
# 26     4-4-2    José Luis Munuera  Match Report    NaN
# 27     4-4-2         José Sánchez  Match Report    NaN
# 28     4-4-2       Alberola Rojas  Match Report    NaN
# 29     4-4-2  Isidro Díaz de Mera  Match Report    NaN
# 30   4-1-4-1        Juan Martínez  Match Report    NaN
# 31     4-4-2  Antonio Matéu Lahoz  Match Report    NaN
# 32     4-4-2         Mario Melero  Match Report    NaN
# 33     4-4-2  Alejandro Hernández  Match Report    NaN
# 34     4-4-2       Adrián Cordero  Match Report    NaN
# 35     4-4-2     Guillermo Cuadra  Match Report    NaN
# 36     4-4-2    José Luis Munuera  Match Report    NaN
# 37   4-2-3-1     Carlos del Cerro  Match Report    NaN
# 38     4-3-3       Pablo González  Match Report    NaN
# 39     4-4-2         José Sánchez  Match Report    NaN
# 40     4-3-3  Isidro Díaz de Mera  Match Report    NaN

# %%
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'all_comps/shooting/' in l]
links
# Out:
# ['/en/squads/8d6fd021/2020-2021/matchlogs/all_comps/shooting/Alaves-Match-Logs-All-Competitions',
#  '/en/squads/8d6fd021/2020-2021/matchlogs/all_comps/shooting/Alaves-Match-Logs-All-Competitions',
#  '/en/squads/8d6fd021/2020-2021/matchlogs/all_comps/shooting/Alaves-Match-Logs-All-Competitions',
#  '/en/squads/8d6fd021/2020-2021/matchlogs/all_comps/shooting/Alaves-Match-Logs-All-Competitions']

# %%
data = requests.get(f"https://fbref.com{links[0]}")
shooting = pd.read_html(data.text, match="Shooting")[0]
shooting.head()
# Out:
#    For Alavés                                                           \
#          Date   Time     Comp        Round  Day Venue Result   GF   GA
# 0  2020-09-13  14:00  La Liga  Matchweek 1  Sun  Home      L  0.0  1.0
# 1  2020-09-20  18:30  La Liga  Matchweek 2  Sun  Away      L  1.0  2.0
# 2  2020-09-26  13:00  La Liga  Matchweek 3  Sat  Home      D  0.0  0.0
# 3  2020-09-30  19:00  La Liga  Matchweek 4  Wed  Away      L  1.0  3.0
# 4  2020-10-04  14:00  La Liga  Matchweek 5  Sun  Home      W  1.0  0.0
#
#                   ... Standard               Expected                    \
#         Opponent  ...     Dist   FK PK PKatt       xG npxG npxG/Sh G-xG
# 0          Betis  ...     11.3  0.0  0     0      1.2  1.2    0.19 -1.2
# 1        Granada  ...     19.0  1.0  0     0      0.7  0.7    0.13  0.3
# 2         Getafe  ...     17.4  1.0  0     0      1.3  1.3    0.15 -1.3
# 3     Villarreal  ...     15.8  0.0  0     0      1.1  1.1    0.14 -0.1
# 4  Athletic Club  ...     17.1  0.0  0     0      0.6  0.6    0.08  0.4
#
#           Unnamed: 25_level_0
#   np:G-xG        Match Report
# 0    -1.2        Match Report
# 1     0.3        Match Report
# 2    -1.3        Match Report
# 3    -0.1        Match Report
# 4     0.4        Match Report
#
# [5 rows x 26 columns]

# %%
shooting.columns=shooting.columns.droplevel()
shooting.columns
# Out:
# Index(['Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result', 'GF', 'GA',
#        'Opponent', 'Gls', 'Sh', 'SoT', 'SoT%', 'G/Sh', 'G/SoT', 'Dist', 'FK',
#        'PK', 'PKatt', 'xG', 'npxG', 'npxG/Sh', 'G-xG', 'np:G-xG',
#        'Match Report'],
#       dtype='object')

# %%
shooting.head()
# Out:
#          Date   Time     Comp        Round  Day Venue Result   GF   GA  \
# 0  2020-09-13  14:00  La Liga  Matchweek 1  Sun  Home      L  0.0  1.0
# 1  2020-09-20  18:30  La Liga  Matchweek 2  Sun  Away      L  1.0  2.0
# 2  2020-09-26  13:00  La Liga  Matchweek 3  Sat  Home      D  0.0  0.0
# 3  2020-09-30  19:00  La Liga  Matchweek 4  Wed  Away      L  1.0  3.0
# 4  2020-10-04  14:00  La Liga  Matchweek 5  Sun  Home      W  1.0  0.0
#
#         Opponent  ...  Dist   FK  PK  PKatt   xG  npxG  npxG/Sh  G-xG  \
# 0          Betis  ...  11.3  0.0   0      0  1.2   1.2     0.19  -1.2
# 1        Granada  ...  19.0  1.0   0      0  0.7   0.7     0.13   0.3
# 2         Getafe  ...  17.4  1.0   0      0  1.3   1.3     0.15  -1.3
# 3     Villarreal  ...  15.8  0.0   0      0  1.1   1.1     0.14  -0.1
# 4  Athletic Club  ...  17.1  0.0   0      0  0.6   0.6     0.08   0.4
#
#    np:G-xG  Match Report
# 0     -1.2  Match Report
# 1      0.3  Match Report
# 2     -1.3  Match Report
# 3     -0.1  Match Report
# 4      0.4  Match Report
#
# [5 rows x 26 columns]

# %%
matches[0].shape
# Out:
# (41, 19)

# %%
team_data = matches[0].merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
team_data.head()
# Out:
#          Date   Time     Comp        Round  Day Venue Result  GF  GA  \
# 0  2020-09-13  14:00  La Liga  Matchweek 1  Sun  Home      L   0   1
# 1  2020-09-20  18:30  La Liga  Matchweek 2  Sun  Away      L   1   2
# 2  2020-09-26  13:00  La Liga  Matchweek 3  Sat  Home      D   0   0
# 3  2020-09-30  19:00  La Liga  Matchweek 4  Wed  Away      L   1   3
# 4  2020-10-04  14:00  La Liga  Matchweek 5  Sun  Home      W   1   0
#
#         Opponent  ...  Formation           Referee  Match Report  Notes   Sh  \
# 0          Betis  ...    3-1-4-2    Pablo González  Match Report    NaN  7.0
# 1        Granada  ...      3-5-2  Carlos del Cerro  Match Report    NaN  5.0
# 2         Getafe  ...      4-4-2    Alberola Rojas  Match Report    NaN  9.0
# 3     Villarreal  ...      4-4-2       David Medié  Match Report    NaN  8.0
# 4  Athletic Club  ...      3-5-2      José Sánchez  Match Report    NaN  8.0
#
#    SoT  Dist   FK  PK  PKatt
# 0  2.0  11.3  0.0   0      0
# 1  3.0  19.0  1.0   0      0
# 2  0.0  17.4  1.0   0      0
# 3  3.0  15.8  0.0   0      0
# 4  3.0  17.1  0.0   0      0
#
# [5 rows x 25 columns]

# %%
team_data.shape
# Out:
# (41, 25)

# %%
years = list(range(2021, 2020, -1))
print(years)
all_matches = []
# Out:
# [2021]

# %%
standings_url = "https://fbref.com/en/comps/12/2022-2023/stats/2022-2023-La-Liga-Stats"

# %%
import time
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
        soup = BeautifulSoup(data.text)
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        shooting = pd.read_html(data.text, match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
        except ValueError:
            continue
        team_data = team_data[team_data["Comp"] == "La Liga"]
        
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(1)

# %%
len(all_matches)
# Out:
# 20

# %%
match_df = pd.concat(all_matches)

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df
# Out:
#           date   time     comp         round  day venue result gf ga  \
# 0   2021-08-14  22:00  La Liga   Matchweek 1  Sat  Home      L  1  4
# 1   2021-08-21  17:00  La Liga   Matchweek 2  Sat  Home      L  0  1
# 2   2021-08-27  22:15  La Liga   Matchweek 3  Fri  Away      L  0  3
# 3   2021-09-18  21:00  La Liga   Matchweek 5  Sat  Home      L  0  2
# 4   2021-09-22  19:30  La Liga   Matchweek 6  Wed  Away      L  0  1
# ..         ...    ...      ...           ...  ...   ...    ... .. ..
# 48  2022-04-30  14:00  La Liga  Matchweek 34  Sat  Away      L  1  2
# 50  2022-05-08  16:15  La Liga  Matchweek 35  Sun  Home      D  1  1
# 51  2022-05-12  20:00  La Liga  Matchweek 36  Thu  Away      W  5  1
# 52  2022-05-15  19:30  La Liga  Matchweek 37  Sun  Home      L  1  2
# 53  2022-05-22  22:00  La Liga  Matchweek 38  Sun  Away      W  2  0
#
#           opponent  ...  match report  notes  sh  sot  dist   fk pk pkatt  \
# 0      Real Madrid  ...  Match Report    NaN  10    3  18.4  1.0  1     1
# 1         Mallorca  ...  Match Report    NaN   9    4  14.8  0.0  0     0
# 2         Valencia  ...  Match Report    NaN   9    2  19.7  1.0  0     0
# 3          Osasuna  ...  Match Report    NaN   8    3  22.6  0.0  0     0
# 4         Espanyol  ...  Match Report    NaN   7    2  14.9  0.0  0     0
# ..             ...  ...           ...    ...  ..  ...   ...  ... ..   ...
# 48          Alavés  ...  Match Report    NaN  16    6  17.6  1.0  0     0
# 50         Sevilla  ...  Match Report    NaN  14    7  13.4  0.0  0     0
# 51  Rayo Vallecano  ...  Match Report    NaN  11    8  12.3  0.0  0     0
# 52   Real Sociedad  ...  Match Report    NaN  10    4  17.0  1.0  0     0
# 53       Barcelona  ...  Match Report    NaN   4    3  12.6  0.0  0     0
#
#    season        team
# 0    2021      Alaves
# 1    2021      Alaves
# 2    2021      Alaves
# 3    2021      Alaves
# 4    2021      Alaves
# ..    ...         ...
# 48   2021  Villarreal
# 50   2021  Villarreal
# 51   2021  Villarreal
# 52   2021  Villarreal
# 53   2021  Villarreal
#
# [760 rows x 27 columns]

# %%
years1 = list(range(2022, 2021, -1))
print(years1)
all_matches1 = []
# Out:
# [2022]

# %%
for year in years1:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
        soup = BeautifulSoup(data.text)
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        shooting = pd.read_html(data.text, match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
        except ValueError:
            continue
        team_data = team_data[team_data["Comp"] == "La Liga"]
        
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(1)

# %%
match_df1 = pd.concat(all_matches)

# %%
match_df1.columns = [c.lower() for c in match_df.columns]
match_df1
# Out:
#           date   time     comp         round  day venue result gf ga  \
# 0   2020-09-13  14:00  La Liga   Matchweek 1  Sun  Home      L  0  1
# 1   2020-09-20  18:30  La Liga   Matchweek 2  Sun  Away      L  1  2
# 2   2020-09-26  13:00  La Liga   Matchweek 3  Sat  Home      D  0  0
# 3   2020-09-30  19:00  La Liga   Matchweek 4  Wed  Away      L  1  3
# 4   2020-10-04  14:00  La Liga   Matchweek 5  Sun  Home      W  1  0
# ..         ...    ...      ...           ...  ...   ...    ... .. ..
# 36  2020-07-05  22:00  La Liga  Matchweek 34  Sun  Home      L  1  4
# 37  2020-07-08  20:30  La Liga  Matchweek 35  Wed  Away      W  3  1
# 38  2020-07-13  19:30  La Liga  Matchweek 36  Mon  Home      L  1  2
# 39  2020-07-16  21:00  La Liga  Matchweek 37  Thu  Away      L  1  2
# 40  2020-07-19  18:30  La Liga  Matchweek 38  Sun  Home      W  4  0
#
#          opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 0           Betis  ...  Match Report    NaN   7.0  2.0  11.3  0.0  0     0
# 1         Granada  ...  Match Report    NaN   5.0  3.0  19.0  1.0  0     0
# 2          Getafe  ...  Match Report    NaN   9.0  0.0  17.4  1.0  0     0
# 3      Villarreal  ...  Match Report    NaN   8.0  3.0  15.8  0.0  0     0
# 4   Athletic Club  ...  Match Report    NaN   8.0  3.0  17.1  0.0  0     0
# ..            ...  ...           ...    ...   ...  ...   ...  ... ..   ...
# 36      Barcelona  ...  Match Report    NaN   9.0  4.0  18.3  0.0  0     0
# 37         Getafe  ...  Match Report    NaN   4.0  1.0  26.9  0.0  2     2
# 38  Real Sociedad  ...  Match Report    NaN   9.0  3.0  21.2  1.0  0     0
# 39    Real Madrid  ...  Match Report    NaN   8.0  4.0  18.6  2.0  0     0
# 40          Eibar  ...  Match Report    NaN  12.0  5.0  14.0  0.0  0     0
#
#    season        team
# 0    2022      Alaves
# 1    2022      Alaves
# 2    2022      Alaves
# 3    2022      Alaves
# 4    2022      Alaves
# ..    ...         ...
# 36   2022  Villarreal
# 37   2022  Villarreal
# 38   2022  Villarreal
# 39   2022  Villarreal
# 40   2022  Villarreal
#
# [1254 rows x 27 columns]

# %%
len(all_matches)
# Out:
# 33

# %%
matches=pd.concat([match_df, match_df1])
matches
# Out:
#           date   time     comp         round  day venue result gf ga  \
# 0   2021-08-14  22:00  La Liga   Matchweek 1  Sat  Home      L  1  4
# 1   2021-08-21  17:00  La Liga   Matchweek 2  Sat  Home      L  0  1
# 2   2021-08-27  22:15  La Liga   Matchweek 3  Fri  Away      L  0  3
# 3   2021-09-18  21:00  La Liga   Matchweek 5  Sat  Home      L  0  2
# 4   2021-09-22  19:30  La Liga   Matchweek 6  Wed  Away      L  0  1
# ..         ...    ...      ...           ...  ...   ...    ... .. ..
# 36  2020-07-05  22:00  La Liga  Matchweek 34  Sun  Home      L  1  4
# 37  2020-07-08  20:30  La Liga  Matchweek 35  Wed  Away      W  3  1
# 38  2020-07-13  19:30  La Liga  Matchweek 36  Mon  Home      L  1  2
# 39  2020-07-16  21:00  La Liga  Matchweek 37  Thu  Away      L  1  2
# 40  2020-07-19  18:30  La Liga  Matchweek 38  Sun  Home      W  4  0
#
#          opponent  ...  match report  notes    sh  sot  dist   fk pk pkatt  \
# 0     Real Madrid  ...  Match Report    NaN  10.0  3.0  18.4  1.0  1     1
# 1        Mallorca  ...  Match Report    NaN   9.0  4.0  14.8  0.0  0     0
# 2        Valencia  ...  Match Report    NaN   9.0  2.0  19.7  1.0  0     0
# 3         Osasuna  ...  Match Report    NaN   8.0  3.0  22.6  0.0  0     0
# 4        Espanyol  ...  Match Report    NaN   7.0  2.0  14.9  0.0  0     0
# ..            ...  ...           ...    ...   ...  ...   ...  ... ..   ...
# 36      Barcelona  ...  Match Report    NaN   9.0  4.0  18.3  0.0  0     0
# 37         Getafe  ...  Match Report    NaN   4.0  1.0  26.9  0.0  2     2
# 38  Real Sociedad  ...  Match Report    NaN   9.0  3.0  21.2  1.0  0     0
# 39    Real Madrid  ...  Match Report    NaN   8.0  4.0  18.6  2.0  0     0
# 40          Eibar  ...  Match Report    NaN  12.0  5.0  14.0  0.0  0     0
#
#    season        team
# 0    2021      Alaves
# 1    2021      Alaves
# 2    2021      Alaves
# 3    2021      Alaves
# 4    2021      Alaves
# ..    ...         ...
# 36   2022  Villarreal
# 37   2022  Villarreal
# 38   2022  Villarreal
# 39   2022  Villarreal
# 40   2022  Villarreal
#
# [2014 rows x 27 columns]

# %%
matches.to_csv("matches.csv")

# %%
matches.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'referee', 'match report', 'notes', 'sh', 'sot', 'dist', 'fk', 'pk',
#        'pkatt', 'season', 'team'],
#       dtype='object')
